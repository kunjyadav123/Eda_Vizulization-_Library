# %% [markdown]
# # EDA(Data Analysis Project) : Diwali Sale

# %%
# Importing Essential Python Libraries: 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
print(np.__version__)
print(pd.__version__)
print(sns.__version__)
# Out:
# 2.2.4
# 2.2.3
# 0.13.2

# %%
# reading dataframe! 
df = pd.read_csv(r"C:\Users\Pankaj Yadav\OneDrive\Desktop\DSC python lbry(venv)\1stVENV\Python_Diwali_Sales_Analysis-main\Diwali Sales Data.csv", encoding= "latin1")
print(df)
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
# Getting shape/  head / tail  of dataset of Diwali sale !

df = pd.read_csv(r"C:\Users\Pankaj Yadav\OneDrive\Desktop\DSC python lbry(venv)\1stVENV\Python_Diwali_Sales_Analysis-main\Diwali Sales Data.csv", encoding = "latin1")
df.shape
print(df.head())
print("\n\n\n\n",df.tail())
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
# Getting crux of data frame in breif!

df = pd.read_csv(r"C:\Users\Pankaj Yadav\OneDrive\Desktop\DSC python lbry(venv)\1stVENV\Python_Diwali_Sales_Analysis-main\Diwali Sales Data.csv", encoding = "latin1")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
# Getting null values data and sum of all null values existed in column data (Seee both step one by one)

# Getting aware about null values  in specific column (For null value it willl be True and for non null value it will show False ) by pd.isnull(df)

# Grab syntax here wisely! pd.isnull(dataframe_name)

df = pd.read_csv(r"C:\Users\Pankaj Yadav\OneDrive\Desktop\DSC python lbry(venv)\1stVENV\Python_Diwali_Sales_Analysis-main\Diwali Sales Data.csv", encoding = "latin1")
pd.isnull(df)
# Out:
#        User_ID  Cust_name  Product_ID  Gender  Age Group    Age  \
# 0        False      False       False   False      False  False
# 1        False      False       False   False      False  False
# 2        False      False       False   False      False  False
# 3        False      False       False   False      False  False
# 4        False      False       False   False      False  False
# ...        ...        ...         ...     ...        ...    ...
# 11246    False      False       False   False      False  False
# 11247    False      False       False   False      False  False
# 11248    False      False       False   False      False  False
# 11249    False      False       False   False      False  False
# 11250    False      False       False   False      False  False
#
#        Marital_Status  State   Zone  Occupation  Product_Category  Orders  \
# 0               False  False  False       False             False   False
# ...

# %%
# Getting sum of all null data in specfic columns means an brief overview of nulll values in  data set's column by pd.isnull(df).sum()

# Grab syntax wisely!  pd.isnull(dataframe_name).sum()

df = pd.read_csv(r"C:\Users\Pankaj Yadav\OneDrive\Desktop\DSC python lbry(venv)\1stVENV\Python_Diwali_Sales_Analysis-main\Diwali Sales Data.csv", encoding = "latin1")
pd.isnull(df).sum()
# Out:
# User_ID                 0
# Cust_name               0
# Product_ID              0
# Gender                  0
# Age Group               0
# Age                     0
# Marital_Status          0
# State                   0
# Zone                    0
# Occupation              0
# Product_Category        0
# Orders                  0
# Amount                 12
# Status              11251
# unnamed1            11251
# dtype: int64

# %%
# deleting colunmns from as dataset(dataframe): pd.drop()   : Its is basicallys used to delete unwanted/ unrelated / blank columns ! 

df = pd.read_csv(r"C:\Users\Pankaj Yadav\OneDrive\Desktop\DSC python lbry(venv)\1stVENV\Python_Diwali_Sales_Analysis-main\Diwali Sales Data.csv", encoding = "latin1")
print(df)


df.drop(columns = ["Amount","Zone"],inplace = True) # its makes changes in actual dataset let now makes changes print then! 
print("\n\n\n\n",df) # now Amount columns got deleted 
 
# one more thing dont ignore inplace = True coz it is very crucial as it saves the changes you done via drop or any other method.
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
# droping null values ! : by   df.dropna(inplace = True)
# see first! 


df = pd.read_csv(r"C:\Users\Pankaj Yadav\OneDrive\Desktop\DSC python lbry(venv)\1stVENV\Python_Diwali_Sales_Analysis-main\Diwali Sales Data.csv", encoding = "latin1")
pd.isnull(df).sum() # see Amount, Status,unnamed1 columns has 12, 11251 and 11251  null values let delete them using dropna method.
# Out:
# User_ID                 0
# Cust_name               0
# Product_ID              0
# Gender                  0
# Age Group               0
# Age                     0
# Marital_Status          0
# State                   0
# Zone                    0
# Occupation              0
# Product_Category        0
# Orders                  0
# Amount                 12
# Status              11251
# unnamed1            11251
# dtype: int64

# %%
# after using dropna method  = nothing left to say means all null values of columns got eliminted .

# inplace  = True makes changes saved if we use any method without inplace = True, it will doest makes changes in dataframe.

df.dropna(inplace = True)
pd.isnull(df).sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# Status              0
# unnamed1            0
# dtype: int64

# %%
# getting nanme of all columns in brief: Remember this method.

df = pd.read_csv(r"C:\Users\Pankaj Yadav\OneDrive\Desktop\DSC python lbry(venv)\1stVENV\Python_Diwali_Sales_Analysis-main\Diwali Sales Data.csv", encoding = "latin1")
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Status', 'unnamed1'],
#       dtype='object')

# %%
# Changing data type of columns elements: 
# working syntax : df["Column_name"] = df["columns_name"].astype("updated_datatype_name")
# to check updated dataframe use   df["Column_name"].dtypes


df = pd.read_csv(r"C:\Users\Pankaj Yadav\OneDrive\Desktop\DSC python lbry(venv)\1stVENV\Python_Diwali_Sales_Analysis-main\Diwali Sales Data.csv", encoding = "latin1")
df["Age"] = df["Age"].astype("float")
df["Age"].dtypes  # makes changes in datatypes of the columns. Here we make int to float!  in columns Age.
# Out:
# dtype('float64')

# %%
# Columns renaming! 
# working syntax :  df.rename(columns = {initial_columms_name : Updated_coloumn_name} , inplace = True)
# inplace = True makes changes in original dataframe if we doest use inplace = True it will only return an dataframe with changes but will not saves the changes you makes. see




df =  pd.read_csv(r"C:\Users\Pankaj Yadav\OneDrive\Desktop\DSC python lbry(venv)\1stVENV\Python_Diwali_Sales_Analysis-main\Diwali Sales Data.csv", encoding = "latin1")
df.rename(columns = {"Zone": "Area"})  # as we did't use inplace  = True so it wll etrur updated datframne but will not malkes changes !
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
df =  pd.read_csv(r"C:\Users\Pankaj Yadav\OneDrive\Desktop\DSC python lbry(venv)\1stVENV\Python_Diwali_Sales_Analysis-main\Diwali Sales Data.csv", encoding = "latin1")
df.rename(columns = {"Zone": "Area"}) 
print(df)  # as we did't use inplace = True it willnot makes changes in actual dataframe.
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
# Now everything is more clear.

df =  pd.read_csv(r"C:\Users\Pankaj Yadav\OneDrive\Desktop\DSC python lbry(venv)\1stVENV\Python_Diwali_Sales_Analysis-main\Diwali Sales Data.csv", encoding = "latin1")
df.rename(columns = {"Zone": "Area"}, inplace = True)
print(df)
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
# df.describe method : Lets see its significance ! 

# This describe method is very powerful tool/method of pandas used to give summmary of descriptave statistic  for numerical column in your dataframe , Donts worry i it is easy to get just be patient.
# Remember one thing this describe method deals with only numerical values ( of  columns ), not to values of other data type.

# Its gives statistic calculation such as
# count, mean, standard deviation, min value,max value, 25%,50%,75% in each data set and this done in column wise.



df =  pd.read_csv(r"C:\Users\Pankaj Yadav\OneDrive\Desktop\DSC python lbry(venv)\1stVENV\Python_Diwali_Sales_Analysis-main\Diwali Sales Data.csv", encoding = "latin1")
print(df.describe())
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount  \
# count  1.125100e+04  11251.000000    11251.000000  11251.000000  11239.000000
# mean   1.003004e+06     35.421207        0.420318      2.489290   9453.610858
# std    1.716125e+03     12.754122        0.493632      1.115047   5222.355869
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      1.500000   5443.000000
# 50%    1.003065e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004430e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000
#
#        Status  unnamed1
# count     0.0       0.0
# mean      NaN       NaN
# std       NaN       NaN
# min       NaN       NaN
# 25%       NaN       NaN
# 50%       NaN       NaN
# 75%       NaN       NaN
# max       NaN       NaN

# %%
# we may  also use  describe method for some desired specific columns 
# Woking Syntax : df[["Col_name1","Col_name2","Col_name3"]].describe()
# using This will return you only the ststistical description of selected columns in dataframe.




df =  pd.read_csv(r"C:\Users\Pankaj Yadav\OneDrive\Desktop\DSC python lbry(venv)\1stVENV\Python_Diwali_Sales_Analysis-main\Diwali Sales Data.csv", encoding = "latin1")
Col_describe_method = df[["Age","Orders","Amount"]].describe() 
print(Col_describe_method)
# Out:
#                 Age        Orders        Amount
# count  11251.000000  11251.000000  11239.000000
# mean      35.421207      2.489290   9453.610858
# std       12.754122      1.115047   5222.355869
# min       12.000000      1.000000    188.000000
# 25%       27.000000      1.500000   5443.000000
# 50%       33.000000      2.000000   8109.000000
# 75%       43.000000      3.000000  12675.000000
# max       92.000000      4.000000  23952.000000

# %% [markdown]
# ### Exploratory Data Analysis :

# %%
df =  pd.read_csv(r"C:\Users\Pankaj Yadav\OneDrive\Desktop\DSC python lbry(venv)\1stVENV\Python_Diwali_Sales_Analysis-main\Diwali Sales Data.csv", encoding = "latin1")
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Status', 'unnamed1'],
#       dtype='object')

# %% [markdown]
# ### Gender :

# %%
df =  pd.read_csv(r"C:\Users\Pankaj Yadav\OneDrive\Desktop\DSC python lbry(venv)\1stVENV\Python_Diwali_Sales_Analysis-main\Diwali Sales Data.csv", encoding = "latin1")

ax = sns.countplot( x = "Gender", data = df)
for bar in ax.containers:
    ax.bar_label(bar)  # using this sections enles to show value at top of bars.
                       # here bar_label is predefined here!

# %%
df =  pd.read_csv(r"C:\Users\Pankaj Yadav\OneDrive\Desktop\DSC python lbry(venv)\1stVENV\Python_Diwali_Sales_Analysis-main\Diwali Sales Data.csv", encoding = "latin1")

sales_gen = df.groupby(["Gender"], as_index = False)["Amount"].sum().sort_values(by = "Amount", ascending = False)

sns.barplot(x = "Gender", y = "Amount", data = sales_gen)
plt.show()

# %% [markdown]
# #####  From above graph we can see that most of buyer are females and even the purchasing powers of females are greater than men.

# %% [markdown]
# ### Age :

# %%
df =  pd.read_csv(r"C:\Users\Pankaj Yadav\OneDrive\Desktop\DSC python lbry(venv)\1stVENV\Python_Diwali_Sales_Analysis-main\Diwali Sales Data.csv", encoding = "latin1")

ax = sns.countplot( x = "Age Group", data = df, hue = "Gender")

for bar in ax.containers :
    ax.bar_label(bar)
plt.show()

# %%
# Total Amount spend vs age groups.

df =  pd.read_csv(r"C:\Users\Pankaj Yadav\OneDrive\Desktop\DSC python lbry(venv)\1stVENV\Python_Diwali_Sales_Analysis-main\Diwali Sales Data.csv", encoding = "latin1")

sales_age = df.groupby(["Age Group"], as_index = False)["Amount"].sum().sort_values(by = "Amount", ascending = False)
sns.barplot(x = "Age Group", y = "Amount", data = sales_age)
plt.show()

# %% [markdown]
# #### From above graph above we can see that most buyers are from age group 26-35 females.

# %% [markdown]
# ### State :

# %%
df =  pd.read_csv(r"C:\Users\Pankaj Yadav\OneDrive\Desktop\DSC python lbry(venv)\1stVENV\Python_Diwali_Sales_Analysis-main\Diwali Sales Data.csv", encoding = "latin1")
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Status', 'unnamed1'],
#       dtype='object')

# %%
# Total numbers of order from top 10 states.
df =  pd.read_csv(r"C:\Users\Pankaj Yadav\OneDrive\Desktop\DSC python lbry(venv)\1stVENV\Python_Diwali_Sales_Analysis-main\Diwali Sales Data.csv", encoding = "latin1")

sales_state = df.groupby(["State"], as_index = False)["Orders"].sum().sort_values(by = "Orders", ascending = True).head(10)
sns.set(rc = {"figure.figsize":(12,8)})  # we initaiate this method to enhance better view coz via this method we may deals with size of interface.
sns.barplot(x = "State", y = "Orders", data = sales_state)
plt.show()

# %%
# Total amount/Sales from top 10 states .
df =  pd.read_csv(r"C:\Users\Pankaj Yadav\OneDrive\Desktop\DSC python lbry(venv)\1stVENV\Python_Diwali_Sales_Analysis-main\Diwali Sales Data.csv", encoding = "latin1")

amount_states = df.groupby(["State"],as_index = False)["Amount"].sum().sort_values(by = "Amount", ascending = False).head(10)
sns.set(rc = {"figure.figsize":(16,8)})  # we initaiate this method to enhance better view coz via this method we may deals with size of interface.
sns.barplot(x = "State",y = "Amount",  data = amount_states)
plt.show()

# %% [markdown]
# #### From analysing above graphs we see that unexpectedily most of orders are from Himanchal Pradeshg, Keral, and Harayana,respectively but total sales amount is  maximum from UP, Maharastra, and karnataka rspectively.

# %% [markdown]
# ## Marital_status :

# %%
df =  pd.read_csv(r"C:\Users\Pankaj Yadav\OneDrive\Desktop\DSC python lbry(venv)\1stVENV\Python_Diwali_Sales_Analysis-main\Diwali Sales Data.csv", encoding = "latin1")

ax = sns.countplot( x = "Marital_Status", data = df)
sns.set(rc = {"figure.figsize":(3,3)})  # we initaiate this method to enhance better view coz via this method we may deals with size of interface.

for bar in ax.containers:
    ax.bar_label(bar)

# %%
data_marital = df.groupby(["Marital_Status","Gender"],as_index = False)["Amount"].sum().sort_values(by = "Amount", ascending = False)
sns.set(rc = {"figure.figsize":(8,5)})  # we initaiate this method to enhance better view coz via this method we may deals with size of interface.

sns.barplot(x = "Marital_Status", y = "Amount",data = data_marital, hue = "Gender")

plt.show()

# %% [markdown]
# #### Analysing above given graphs we got that most buyers are working womens  and they have high purchasing power.

# %% [markdown]
# ## Occupation :

# %%
df =  pd.read_csv(r"C:\Users\Pankaj Yadav\OneDrive\Desktop\DSC python lbry(venv)\1stVENV\Python_Diwali_Sales_Analysis-main\Diwali Sales Data.csv", encoding = "latin1")
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Status', 'unnamed1'],
#       dtype='object')

# %%
df =  pd.read_csv(r"C:\Users\Pankaj Yadav\OneDrive\Desktop\DSC python lbry(venv)\1stVENV\Python_Diwali_Sales_Analysis-main\Diwali Sales Data.csv", encoding = "latin1")

sns.countplot(x = "Occupation", data = df )
sns.set( rc = {"figure.figsize" :(25,5)})
plt.show()

# %%
data_Occupation = df.groupby(["Occupation"], as_index = False)["Amount"].sum().sort_values(by = "Amount", ascending = False)
sns.set( rc = {"figure.figsize" :(20,5)})

px = sns.barplot(x = "Occupation", y = "Amount", data = data_Occupation)
for alpha in ax.containers:
    px.bar_label(alpha)

# %% [markdown]
# ####  After analysing above graphs we noticed that most buyers are from the IT, avaition and Healthcare sector.

# %% [markdown]
# ### Product_Category:

# %%
df =  pd.read_csv(r"C:\Users\Pankaj Yadav\OneDrive\Desktop\DSC python lbry(venv)\1stVENV\Python_Diwali_Sales_Analysis-main\Diwali Sales Data.csv", encoding = "latin1")
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Status', 'unnamed1'],
#       dtype='object')

# %%
df =  pd.read_csv(r"C:\Users\Pankaj Yadav\OneDrive\Desktop\DSC python lbry(venv)\1stVENV\Python_Diwali_Sales_Analysis-main\Diwali Sales Data.csv", encoding = "latin1")

ax = sns.countplot( x = "Product_Category", data = df)
sns.set(rc = {"figure.figsize":(30,6)})
for bar in ax.containers:
    ax.bar_label(bar)

# %%
sales_Product_Category = df.groupby(["Product_Category"], as_index = False)["Amount"].sum().sort_values("Amount", ascending = False)
px = sns.barplot( x = "Product_Category", y = "Amount", data = sales_Product_Category)
sns.set(rc = {"figure.figsize" : (30,6)})
for aplha in px.containers:
    px.bar_label(alpha)

# %% [markdown]
# #### From above graph it is clear that most of sold products are  Food, Clothing, footware and Electronics.

# %%
# Top 10 sold product (same thing or different) ! 

sales_product_Topten = df.groupby(["Product_Category"], as_index = False)["Amount"].sum().sort_values(by = "Amount", ascending = False).head(10)
rx = sns.barplot( x = "Product_Category", y = "Amount",data = sales_product_Topten)
sns.set( rc = {"figure.figsize": (15,6)})

for beTa in rx.containers:
    rx.bar_label(beTa)

# %% [markdown]
# ## Conclusion :

# %% [markdown]
# #### Married womens between age group 26 to 35 from UP, Maharastra and karnataka working in IT, Healthcare and Avaition are most likely to buy products of clothing, footware and electronics category.

# %%
#COMPLETE PROJECTS ON  (Github ):  https://github.com/kunjyadav123/Data-Analysis_repo


# Thanks You!
